# %%
"""
TOF:counting dE/dx and time difference of TOF
@aurthor Jiancheng Zeng
@September 20 2021
"""

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics
from numpy import array
import pandas as pd

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton.dat")
print("finish reading data!")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""
print("\n Recognize events ...")
s = 0
for s in range(len(event[:,0])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)

identical.append(len(event))
# Out:
# Reading data ...
# finish reading data!
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process:99%

# %%
TOF_out_pbar_E = []
TOF_out_pbar_T = []
TOF_in_pbar_E = []
TOF_in_pbar_T = []

for i in range(len(selection)):
    tempout = 0
    tempin = 0
    for j in range(selection[i].shape[0]):
        if(selection[i][j][6] == 'LAr' and selection[i][j][3] == '-2212'):
            for m in range(selection[i].shape[0]):
                if(selection[i][m][5] == '-11000' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                elif(selection[i][m][5] == '-10000' and selection[i][m][3] == '-2212'):
                    tempout = tempout + float(selection[i][m][9])
            TOF_out_pbar_E.append(tempout)
            TOF_in_pbar_E.append(tempin)
            break
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-2212'):
            for o in range(selection[i].shape[0]):
                if(selection[i][o][5] == '-11000' and selection[i][o][3] == '-2212'):
                    TOF_in_pbar_T.append(selection[i][o][7])
                    break
            for p in range(selection[i].shape[0]):
                if(selection[i][p][5] == '-10000' and selection[i][p][3] == '-2212'):
                    TOF_out_pbar_T.append(selection[i][p][7])
                    break
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification finished!")
# Out:
# TOF data process:99%
#  identification finished!

# %%
#dE_pbar = array([float(i) for i in TOF_out_pbar_E]) - array([float(i) for i in TOF_in_pbar_E])
time_pbar = array([float(i) for i in TOF_in_pbar_T]) - array([float(i) for i in TOF_out_pbar_T])
dEOut_pbar = array([float(i) for i in TOF_out_pbar_E])
dEIn_pbar = array([float(i) for i in TOF_in_pbar_E])
#plt.scatter(time_pbar, dE_pbar)
plt.scatter(time_pbar, dEOut_pbar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_pbar, dEIn_pbar,marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiproton TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/time_antiproton.txt', time_pbar, delimiter = '\t ', fmt='%.6s')
print("finished!")
# Out:
# finished!

# %%
data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_0.dat")
print("finish reading data!")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""
print("\n Recognize events ...")
s = 0
for s in range(len(event[:,0])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)

identical.append(len(event))
print("\n finished!")

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []

for i in range(len(selection)):
    tempout = 0
    tempin = 0
    for j in range(selection[i].shape[0]):
        if(selection[i][j][6] == 'LAr' and selection[i][j][3] == '-1000020030'):
            for m in range(selection[i].shape[0]):
                if(selection[i][m][5] == '-11000' and selection[i][m][3] == '-1000020030'):
                    tempin = tempin + float(selection[i][m][9])
                elif(selection[i][m][5] == '-10000' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            TOF_out_He3bar_E.append(tempout)
            TOF_in_He3bar_E.append(tempin)
            break
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for o in range(selection[i].shape[0]):
                if(selection[i][o][5] == '-11000' and selection[i][o][3] == '-1000020030'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(selection[i].shape[0]):
                if(selection[i][p][5] == '-10000' and selection[i][p][3] == '-1000020030'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification finished!")

print(len(TOF_out_He3bar_E))
print(len(TOF_in_He3bar_E))
print(len(TOF_out_He3bar_T))
print(len(TOF_in_He3bar_T))

#dE_He3bar = array([float(i) for i in TOF_out_He3bar_E]) - array([float(i) for i in TOF_in_pbar_E])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE)
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
plt.grid(alpha = 0.2)
#plt.axis([8, 12, 8, 16])
# Out:
# Reading data ...
# finish reading data!
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process:99%
#  finished!
# TOF data process:99%
#  identification finished!
# 3862
# 3862
# 3862
# 3862

# %%
data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_45_0.dat")
print("finish reading data!")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""
print("\n Recognize events ...")
s = 0
for s in range(len(event[:,0])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)

identical.append(len(event))
print("\n finished!")

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []

for i in range(len(selection)):
    tempout = 0
    tempin = 0
    for j in range(selection[i].shape[0]):
        if(selection[i][j][6] == 'LAr' and selection[i][j][3] == '-1000020030'):
            for m in range(selection[i].shape[0]):
                if(selection[i][m][5] == '-11000' and selection[i][m][3] == '-1000020030'):
                    tempin = tempin + float(selection[i][m][9])
                elif(selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            TOF_out_He3bar_E.append(tempout)
            TOF_in_He3bar_E.append(tempin)
            break
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for o in range(selection[i].shape[0]):
                if(selection[i][o][5] == '-11000' and selection[i][o][3] == '-1000020030'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(selection[i].shape[0]):
                if(selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification finished!")

print(len(TOF_out_He3bar_E))
print(len(TOF_in_He3bar_E))
print(len(TOF_out_He3bar_T))
print(len(TOF_in_He3bar_T))

#dE_He3bar = array([float(i) for i in TOF_out_He3bar_E]) - array([float(i) for i in TOF_in_pbar_E])
time_He3bar_45 = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar_45 = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar_45 = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE)
plt.scatter(time_He3bar_45, dEOut_He3bar_45, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar_45, dEIn_He3bar_45, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF 45 degree')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
plt.grid(alpha = 0.2)
#plt.axis([8, 12, 8, 16])
# Out:
# Reading data ...
# finish reading data!
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process:99%
#  finished!
# TOF data process:99%
#  identification finished!
# 2896
# 2896
# 2896
# 2896

# %%
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'cornflowerblue', label = 'TOF out layer 0 degree')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'royalblue', label = 'TOF inner layer 0 degree')
plt.scatter(time_He3bar_45, dEOut_He3bar_45, marker = '.', color = 'lightcoral', label = 'TOF out layer 45 degree')
plt.scatter(time_He3bar_45, dEIn_He3bar_45, marker = '.', color = 'indianred', label = 'TOF inner layer degree')
plt.title('angle difference')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
plt.grid(alpha = 0.2)

# %%
plt.scatter(time_pbar, dEOut_pbar, marker = '.', color = 'cornflowerblue', label = 'antiproton TOF out layer')
plt.scatter(time_pbar, dEIn_pbar, marker = '.', color = 'royalblue', label = 'anti proton TOF inner layer')
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'lightcoral', label = 'antiHe3 TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'indianred', label = 'antiHe3 TOF inner layer')
plt.title('TOF info')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='upper right')
plt.grid(alpha = 0.2)
#plt.axis([0, 140, 0, 80])

# %%
plt.scatter(time_pbar, dEOut_pbar, marker = '.', color = 'cornflowerblue', label = 'antiproton TOF out layer')
#plt.scatter(time_pbar, dEIn_pbar, marker = '.', color = 'royalblue', label = 'anti proton TOF inner layer')
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'lightcoral', label = 'antiHe3 TOF out layer')
#plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'indianred', label = 'antiHe3 TOF inner layer')
plt.title('TOF info')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='upper right')
plt.grid(alpha = 0.2)
#plt.axis([0, 20, 0, 20])

# %%
#plt.scatter(time_pbar, dEOut_pbar, marker = '.', color = 'cornflowerblue', label = 'antiproton TOF out layer')
plt.scatter(time_pbar, dEIn_pbar, marker = '.', color = 'royalblue', label = 'anti proton TOF inner layer')
#plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'lightcoral', label = 'antiHe3 TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'indianred', label = 'antiHe3 TOF inner layer')
plt.title('TOF info')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='upper right')
plt.grid(alpha = 0.2)
#plt.axis([0, 140, 0, 80])

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection='3d')
TOF_He3bar = [time_He3bar, dEOut_He3bar, dEIn_He3bar]

ax.scatter3D(dEOut_He3bar, dEIn_He3bar, time_He3bar, marker = '.', color = 'indianred', label = 'antiHe3')
#ax.scatter3D(dEOut_He3bar_45, dEIn_He3bar_45, time_He3bar_45, marker = '.', color = 'lightcoral', label = 'antiHe3 45 degree')
ax.scatter3D(dEOut_pbar, dEIn_pbar, time_pbar, marker = '.', color = 'royalblue', label = 'anti proton')

ax.set_xlabel("Out TOF dE [MeV]")
ax.set_ylabel('Inner TOF dE [MeV]')
ax.set_zlabel('time [ns]')
plt.legend()
plt.savefig("./TOF3D.jpg")
plt.show()

# %%
data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_45_5.dat")
print("finish reading data!")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""
print("\n Recognize events ...")
s = 0
for s in range(len(event[:,0])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)

identical.append(len(event))
print("\n finished!")

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []

for i in range(len(selection)):
    tempout = 0
    tempin = 0
    for j in range(selection[i].shape[0]):
        if(selection[i][j][6] == 'LAr' and selection[i][j][3] == '-2212'):
            for m in range(selection[i].shape[0]):
                if(selection[i][m][5] == '-11000' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                elif(selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                    tempout = tempout + float(selection[i][m][9])
            TOF_out_pbar_E.append(tempout)
            TOF_in_pbar_E.append(tempin)
            break
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-2212'):
            for o in range(selection[i].shape[0]):
                if(selection[i][o][5] == '-11000' and selection[i][o][3] == '-2212'):
                    TOF_in_pbar_T.append(selection[i][o][7])
                    break
            for p in range(selection[i].shape[0]):
                if(selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_pbar_T.append(selection[i][p][7])
                    break
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification finished!")

#dE_He3bar = array([float(i) for i in TOF_out_pbar_E]) - array([float(i) for i in TOF_in_pbar_E])
time_pbar_45 = array([float(i) for i in TOF_in_pbar_T]) - array([float(i) for i in TOF_out_pbar_T])
dEOut_pbar_45 = array([float(i) for i in TOF_out_pbar_E])
dEIn_pbar_45 = array([float(i) for i in TOF_in_pbar_E])
#plt.scatter(time_He3bar, dE)
plt.scatter(time_pbar_45, dEOut_pbar_45, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_pbar_45, dEIn_pbar_45, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiproton TOF 45 degree')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
plt.grid(alpha = 0.2)
#plt.axis([8, 12, 8, 16])
# Out:
# Reading data ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/jy/kzbmcbld7cxb685lxm7tb8p80000gn/T/ipykernel_46176/832987971.py in <module>
#       8 """
#       9 print("Reading data ...")
# ---> 10 data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_45_5.dat")
#      11 print("finish reading data!")
#      12
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, encoding_errors, delim_whitespace, low_memory, memory_map, float_precision)
#     681     kwds.update(kwds_defaults)
#     682
# --> 683     return _read(filepath_or_buffer, kwds)
#     684
#     685
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     699         if ioargs.encoding and "b" not in ioargs.mode:
#     700             # Encoding
# --> 701             handle = open(
#     702                 handle,
#     703                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_45_5.dat'

# %%
plt.scatter(dEOut_pbar[time_pbar>11], dEIn_pbar[time_pbar>11], label = "anti proton", marker = '.')
#plt.scatter(dEOut_pbar, dEIn_pbar)
plt.scatter(dEOut_He3bar[time_He3bar > 11] , dEIn_He3bar[time_He3bar >11], label = "anti He3", marker = '.')

plt.grid(alpha = 0.2)
plt.legend()
plt.title("TOF time more than 11ns")
plt.xlabel('Out TOF dE [MeV]')
plt.ylabel('Inner TOF dE [MeV]')
plt.savefig("./slice.jpg")

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection='3d')
TOF_He3bar = [time_He3bar, dEOut_He3bar, dEIn_He3bar]

ax.scatter3D(dEOut_He3bar_45, dEIn_He3bar_45, time_He3bar_45, marker = '.', color = 'indianred', label = 'antiHe3 45 degree')
#ax.scatter3D(dEOut_He3bar_45, dEIn_He3bar_45, time_He3bar_45, marker = '.', color = 'lightcoral', label = 'antiHe3 45 degree')
ax.scatter3D(dEOut_pbar_45, dEIn_pbar_45, time_pbar_45, marker = '.', color = 'royalblue', label = 'anti proton 45 degree')

ax.set_xlabel("Out TOF dE [MeV]")
ax.set_ylabel('Inner TOF dE [MeV]')
ax.set_zlabel('time [ns]')
plt.legend()
plt.savefig("./TOF3D.jpg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jy/kzbmcbld7cxb685lxm7tb8p80000gn/T/ipykernel_46176/1344404401.py in <module>
#       9 ax.scatter3D(dEOut_He3bar_45, dEIn_He3bar_45, time_He3bar_45, marker = '.', color = 'indianred', label = 'antiHe3 45 degree')
#      10 #ax.scatter3D(dEOut_He3bar_45, dEIn_He3bar_45, time_He3bar_45, marker = '.', color = 'lightcoral', label = 'antiHe3 45 degree')
# ---> 11 ax.scatter3D(dEOut_pbar_45, dEIn_pbar_45, time_pbar_45, marker = '.', color = 'royalblue', label = 'anti proton 45 degree')
#      12
#      13 ax.set_xlabel("Out TOF dE [MeV]")
#
# NameError: name 'dEOut_pbar_45' is not defined

# %%
plt.scatter(dEOut_pbar_45[np.logical_and(time_pbar_45>11, time_pbar_45<12)], dEIn_pbar_45[np.logical_and(time_pbar_45>11, time_pbar_45<12)], label = "anti proton 45 degree", marker = '.')
#plt.scatter(dEOut_pbar, dEIn_pbar)
plt.scatter(dEOut_He3bar_45[np.logical_and(time_He3bar_45 > 11, time_He3bar_45 < 12)] , dEIn_He3bar_45[np.logical_and(time_He3bar_45 >11, time_He3bar_45 <12)], label = "anti He3 45 degree", marker = '.')

plt.grid(alpha = 0.2)
plt.legend()
plt.title("TOF time between [11, 12]ns")
plt.xlabel('Out TOF dE [MeV]')
plt.ylabel('Inner TOF dE [MeV]')
plt.savefig("./slice45.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jy/kzbmcbld7cxb685lxm7tb8p80000gn/T/ipykernel_46176/1188409353.py in <module>
# ----> 1 plt.scatter(dEOut_pbar_45[np.logical_and(time_pbar_45>11, time_pbar_45<12)], dEIn_pbar_45[np.logical_and(time_pbar_45>11, time_pbar_45<12)], label = "anti proton 45 degree", marker = '.')
#       2 #plt.scatter(dEOut_pbar, dEIn_pbar)
#       3 plt.scatter(dEOut_He3bar_45[np.logical_and(time_He3bar_45 > 11, time_He3bar_45 < 12)] , dEIn_He3bar_45[np.logical_and(time_He3bar_45 >11, time_He3bar_45 <12)], label = "anti He3 45 degree", marker = '.')
#       4
#       5 plt.grid(alpha = 0.2)
#
# NameError: name 'dEOut_pbar_45' is not defined

# %%
print(type(time_pbar))
# Out:
# <class 'numpy.ndarray'>
