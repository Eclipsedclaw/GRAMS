# %%
"""
plot LArTPC penetration depth for three particles
@aurthor Jiancheng Zeng
@Oct 29 2021
"""
# Out:
# '\nplot LArTPC penetration depth for three particles\n@aurthor Jiancheng Zeng\n@Oct 29 2021\n'

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics
from numpy import array
import pandas as pd
import math
pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# %%
anti_proton = np.array(pd.read_table("/Users/jiancheng/GRAMS/data/TOF/No_Button_GRASP_anti_proton_1e8_MeV_vector.txt", delimiter = ' '))
#anti_deuteron = np.array(pd.read_table("/Users/jiancheng/GRAMS/data/TOF/No_button_GRASP_anti_deuteron_1e8_MeV_Vector.txt", delimiter = ' '))
anti_He3 = np.array(pd.read_table("/Users/jiancheng/GRAMS/data/TOF/No_Button_GRASP_anti_He3_1e8_MeV_vector.txt", delimiter = ' '))
print("Finish reading data!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/jy/kzbmcbld7cxb685lxm7tb8p80000gn/T/ipykernel_41124/2339480662.py in <module>
# ----> 1 anti_proton = np.array(pd.read_table("/Users/jiancheng/GRAMS/data/TOF/No_Button_GRASP_anti_proton_1e8_MeV_vector.txt", delimiter = ' '))
#       2 #anti_deuteron = np.array(pd.read_table("/Users/jiancheng/GRAMS/data/TOF/No_button_GRASP_anti_deuteron_1e8_MeV_Vector.txt", delimiter = ' '))
#       3 anti_He3 = np.array(pd.read_table("/Users/jiancheng/GRAMS/data/TOF/No_Button_GRASP_anti_He3_1e8_MeV_vector.txt", delimiter = ' '))
#       4 print("Finish reading data!")
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
# ...

# %%
plt.hist(anti_proton[:, 6], bins = 40, label = "antiproton %d events"%len(anti_proton[:, 6]), color = 'b')

plt.title('antiproton stop events distance in LArTPC')
plt.xlabel('Penetration Distance/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("Number of events less than 1.6m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<160])/len(anti_proton[:, 6])))
print("Number of events less than 1.4m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<140])/len(anti_proton[:, 6])))
print("Number of events less than 1.2m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<120])/len(anti_proton[:, 6])))
print("Number of events less than 1.0m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<100])/len(anti_proton[:, 6])))
print("Number of events less than 0.8m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<80])/len(anti_proton[:, 6])))
print("Number of events less than 0.6m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<60])/len(anti_proton[:, 6])))
print("Number of events less than 0.4m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<40])/len(anti_proton[:, 6])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jy/kzbmcbld7cxb685lxm7tb8p80000gn/T/ipykernel_41124/2857163293.py in <module>
# ----> 1 plt.hist(anti_proton[:, 6], bins = 40, label = "antiproton %d events"%len(anti_proton[:, 6][anti_proton[:, 6]>0]), color = 'b')
#       2
#       3 plt.title('antiproton stop events distance in LArTPC')
#       4 plt.xlabel('Penetration Distance/cm')
#       5 plt.ylabel('number of events')
#
# NameError: name 'plt' is not defined

# %%
plt.hist(anti_deuteron[:, 6], bins = 40, label = "antideuteron %d events"%len(anti_deuteron[:, 6]), color = 'b')

plt.title('antideuteron stop events distance in LArTPC')
plt.xlabel('Penetration Distance/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("Number of events less than 1.6m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<400])/len(anti_deuteron[:, 6])))
print("Number of events less than 1.4m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<120])/len(anti_deuteron[:, 6])))
print("Number of events less than 1.2m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<110])/len(anti_deuteron[:, 6])))
print("Number of events less than 1.0m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<100])/len(anti_deuteron[:, 6])))
print("Number of events less than 0.8m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<90])/len(anti_deuteron[:, 6])))
print("Number of events less than 0.6m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<80])/len(anti_deuteron[:, 6])))
print("Number of events less than 0.4m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<70])/len(anti_deuteron[:, 6])))

# %%
plt.hist(anti_He3[:, 6], bins = 40, label = "antiHe3 %d events"%len(anti_He3[:, 6]), color = 'b')

plt.title('antiproton stop events distance in LArTPC')
plt.xlabel('Penetration Distance/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("Number of events less than 1.6m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<160])/len(anti_He3[:, 6])))
print("Number of events less than 1.4m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<140])/len(anti_He3[:, 6])))
print("Number of events less than 1.2m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<120])/len(anti_He3[:, 6])))
print("Number of events less than 1.0m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<100])/len(anti_He3[:, 6])))
print("Number of events less than 0.8m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<80])/len(anti_He3[:, 6])))
print("Number of events less than 0.6m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<60])/len(anti_He3[:, 6])))
print("Number of events less than 0.4m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<40])/len(anti_He3[:, 6])))
# Out:
# Number of events less than 1.6m:0.9958768061381807
# Number of events less than 1.4m:0.9781829263920261
# Number of events less than 1.2m:0.9235954250475064
# Number of events less than 1.0m:0.8337815065791833
# Number of events less than 0.8m:0.7217023412570364
# Number of events less than 0.6m:0.6033846043526586
# Number of events less than 0.4m:0.4874152952565344

# %%
plt.hist(anti_proton[:, 7], bins = 40, range = (0, 20), label = "antiproton %d events"%len(anti_proton[:, 7]), color = 'b')

plt.title('antiproton stop events depth in LArTPC')
plt.xlabel('Penetration Depth/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("Number of events less than 18cm:"+str(len(anti_proton[:, 7][anti_proton[:, 7]<18])/len(anti_proton[:, 7])))
print("Number of events less than 16cm:"+str(len(anti_proton[:, 7][anti_proton[:, 7]<16])/len(anti_proton[:, 7])))
print("Number of events less than 15cm:"+str(len(anti_proton[:, 7][anti_proton[:, 7]<15])/len(anti_proton[:, 7])))
print("Number of events less than 14cm:"+str(len(anti_proton[:, 7][anti_proton[:, 7]<14])/len(anti_proton[:, 7])))
print("Number of events less than 12cm:"+str(len(anti_proton[:, 7][anti_proton[:, 7]<12])/len(anti_proton[:, 7])))
print("Number of events less than 10cm:"+str(len(anti_proton[:, 7][anti_proton[:, 7]<10])/len(anti_proton[:, 7])))
print("Number of events less than 8cm:"+str(len(anti_proton[:, 7][anti_proton[:, 7]<8])/len(anti_proton[:, 7])))
print("Number of events less than 6cm:"+str(len(anti_proton[:, 7][anti_proton[:, 7]<6])/len(anti_proton[:, 7])))
# Out:
# Number of events less than 18cm:0.9334466996364998
# Number of events less than 16cm:0.8623535468572052
# Number of events less than 15cm:0.8250362720167241
# Number of events less than 14cm:0.7864709277835847
# Number of events less than 12cm:0.70481598776892
# Number of events less than 10cm:0.6168426964539229
# Number of events less than 8cm:0.5165135181516092
# Number of events less than 6cm:0.4101468041623114

# %%
plt.hist(anti_deuteron[:, 7], bins = 40, range = (0, 20), label = "antideuteron %d events"%len(anti_deuteron[:, 7]), color = 'b')

plt.title('antideuteron stop events depth in LArTPC')
plt.xlabel('Penetration Depth/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("Number of events less than 18cm:"+str(len(anti_deuteron[:, 7][anti_deuteron[:, 7]<18])/len(anti_deuteron[:, 7])))
print("Number of events less than 16cm:"+str(len(anti_deuteron[:, 7][anti_deuteron[:, 7]<16])/len(anti_deuteron[:, 7])))
print("Number of events less than 15cm:"+str(len(anti_deuteron[:, 7][anti_deuteron[:, 7]<15])/len(anti_deuteron[:, 7])))
print("Number of events less than 14cm:"+str(len(anti_deuteron[:, 7][anti_deuteron[:, 7]<14])/len(anti_deuteron[:, 7])))
print("Number of events less than 12cm:"+str(len(anti_deuteron[:, 7][anti_deuteron[:, 7]<12])/len(anti_deuteron[:, 7])))
print("Number of events less than 10cm:"+str(len(anti_deuteron[:, 7][anti_deuteron[:, 7]<10])/len(anti_deuteron[:, 7])))
print("Number of events less than 8cm:"+str(len(anti_deuteron[:, 7][anti_deuteron[:, 7]<8])/len(anti_deuteron[:, 7])))
print("Number of events less than 6cm:"+str(len(anti_deuteron[:, 7][anti_deuteron[:, 7]<6])/len(anti_deuteron[:, 7])))

# %%
plt.hist(anti_He3[:, 7], bins = 40, range = (0, 20), label = "antiHe3 %d events"%len(anti_He3[:, 7]), color = 'b')

plt.title('antiHe3 stop events depth in LArTPC')
plt.xlabel('Penetration Depth/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("Number of events less than 18cm:"+str(len(anti_He3[:, 7][anti_He3[:, 7]<18])/len(anti_He3[:, 7])))
print("Number of events less than 16cm:"+str(len(anti_He3[:, 7][anti_He3[:, 7]<16])/len(anti_He3[:, 7])))
print("Number of events less than 14cm:"+str(len(anti_He3[:, 7][anti_He3[:, 7]<14])/len(anti_He3[:, 7])))
print("Number of events less than 12cm:"+str(len(anti_He3[:, 7][anti_He3[:, 7]<12])/len(anti_He3[:, 7])))
print("Number of events less than 10cm:"+str(len(anti_He3[:, 7][anti_He3[:, 7]<10])/len(anti_He3[:, 7])))
print("Number of events less than 8cm:"+str(len(anti_He3[:, 7][anti_He3[:, 7]<8])/len(anti_He3[:, 7])))
print("Number of events less than 6cm:"+str(len(anti_He3[:, 7][anti_He3[:, 7]<6])/len(anti_He3[:, 7])))
# Out:
# Number of events less than 18cm:0.9395503925997634
# Number of events less than 16cm:0.8756050338818974
# Number of events less than 14cm:0.8051342727044566
# Number of events less than 12cm:0.7272955433652433
# Number of events less than 10cm:0.6413179878813954
# Number of events less than 8cm:0.5467713599368972
# Number of events less than 6cm:0.4372198917213438
