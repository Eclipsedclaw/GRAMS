# %%
"""
read and modify TOF data for antiHe3
@aurthor Jiancheng Zeng
@Oct 15 2021
"""
# Out:
# '\nread and modify TOF data for antiHe3\n@aurthor Jiancheng Zeng\n@Oct 15 2021\n'

# %%
"""
antiHe3 analysis
"""

import numpy as np
import matplotlib.pyplot as plt
import statistics
from numpy import array
import pandas as pd

# %%
data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
#data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_1.txt")    #input file
data = pd.read_table("～/GRAMS/Toy\ model/data/cut/TOF_anti_He3_1e4_0_1500_0_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            print(theta)
            print(theta0)
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
# Out:
# Reading data ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/jy/kzbmcbld7cxb685lxm7tb8p80000gn/T/ipykernel_12983/2437292675.py in <module>
#       9 print("Reading data ...")
#      10 #data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_1.txt")    #input file
# ---> 11 data = pd.read_table("～/GRAMS/Toy model/data/cut/TOF_anti_He3_1e4_0_1500_0_4.dat")
#      12
#      13 """
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, encoding_errors, delim_whitespace, low_memory, memory_map, float_precision)
#     681     kwds.update(kwds_defaults)
#     682
# --> 683     return _read(filepath_or_buffer, kwds)
#     684
#     685
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     699         if ioargs.encoding and "b" not in ioargs.mode:
#     700             # Encoding
# --> 701             handle = open(
#     702                 handle,
#     703                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '～/GRAMS/Toy model/data/cut/TOF_anti_He3_1e4_0_1500_0_4.dat'

# %%
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_2.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_3.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_4.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_5.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_6.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_7.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_8.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_9.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_10.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_11.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_12.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_13.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:99%
#  finished!
#
#  Recognize events ...
# Recognizing process finished!
#
# TOF data process:99%
#  identification:finished!
# finished!

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_14.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
# Out:
# Reading data ...
# Modifing data ...
# Modifing process:38%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/jy/kzbmcbld7cxb685lxm7tb8p80000gn/T/ipykernel_12983/3306127277.py in <module>
#      22     if(0 <= data.iloc[i,2] <= 1):
#      23         event.append(list(data.iloc[i,:]))
# ---> 24     print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
#      25 event = np.array(event)
#      26 print("\n finished!")
#
# ~/.local/lib/python3.9/site-packages/ipykernel/iostream.py in write(self, string)
#     517             is_child = (not self._is_master_process())
#     518             # only touch the buffer in the IO thread to avoid races
# --> 519             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     520             if is_child:
#     521                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/.local/lib/python3.9/site-packages/ipykernel/iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~/.local/lib/python3.9/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     539                 )
#     540             data.group = group
# --> 541         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     542
#     543     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/.local/lib/python3.9/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_15.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_16.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_17.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")

# %%
"""
antiHe3 analysis
"""

data = []
event = []
identical = []

"""
Read data from total data file
--------------------
"""
print("Reading data ...")
data = pd.read_table("~/CloudDocuments/Documents/GitHub/GRAMS/sensitivity/data/TOF_data/TOF_anti_He3_1e7_0_1500_0_4_18.txt")    #input file
#data = pd.read_table("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e4_0_500_45_4.dat")

"""
modification
"""
print("Modifing data ...")
for i in range(len(data.iloc[:,0])):
    if(0 <= data.iloc[i,2] <= 1):
        event.append(list(data.iloc[i,:]))
    print("Modifing process:"+str(int(100*i/len(data.iloc[:,0])))+"%", end='\r')
event = np.array(event)
print("\n finished!")

"""
recognize the data file length distribution
"""

print("\n Recognize events ...")
s = 0
for s in range(len(event[:,1])-1):
    if(int(event[s,0]) != int(event[s+1,0])):
        identical.append(s+1)
    print("Recognizing process:"+str(int(100*s/len(event[:,0])))+"%", end='\r')
    #time.sleep(0.001)
selection = np.split(event, identical)
print("Recognizing process finished!\n")
identical.append(len(event))

TOF_out_He3bar_E = []
TOF_out_He3bar_T = []
TOF_in_He3bar_E = []
TOF_in_He3bar_T = []
index = []

for i in range(1, len(selection)-1, 1):
    tempout = 0
    tempin = 0
    for k in range(selection[i].shape[0]):
        if(selection[i][k][6] == 'LAr' and selection[i][k][3] == '-1000020030'):
            for m in range(k):
                if(selection[i][m][5] == '-11000' or selection[i][m][5] == '-11004' and selection[i][m][3] == '-1000020030'):
                #if(selection[i][m][5] == '-11004' and selection[i][m][3] == '-2212'):
                    tempin = tempin + float(selection[i][m][9])
                #elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-2212'):
                elif(selection[i][m][5] == '-10000' or selection[i][m][5] == '-10005' and selection[i][m][3] == '-1000020030'):
                    tempout = tempout + float(selection[i][m][9])
            if(tempin != 0 and tempout != 0):
                TOF_out_He3bar_E.append(tempout)
                TOF_in_He3bar_E.append(tempin)
                index.append(selection[i][k][0])
            for o in range(k):
                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11001' or selection[i][o][5] == '-11002' or selection[i][o][5] == '-11003' or selection[i][o][5] == '-11004' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-1000020030'):
#                if(selection[i][o][5] == '-11000' or selection[i][o][5] == '-11005' and selection[i][o][3] == '-2212'):
                    TOF_in_He3bar_T.append(selection[i][o][7])
                    break
            for p in range(k):
                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10001' or selection[i][p][5] == '-10002' or selection[i][p][5] == '-10003' or selection[i][p][5] == '-10004' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-1000020030'):
#                if(selection[i][p][5] == '-10000' or selection[i][p][5] == '-10005' and selection[i][p][3] == '-2212'):
                    TOF_out_He3bar_T.append(selection[i][p][7])
                    break
            theta = np.arctan((float(selection[i][p][18])-float(selection[i][k][18]))/np.sqrt((float(selection[i][p][17])-float(selection[i][k][17])) ** 2 + (float(selection[i][p][16])-float(selection[i][k][16])) ** 2))
            theta0 = np.arctan((210 - float(selection[i][0][18]))/np.sqrt((float(selection[i][0][17])-0) ** 2 + (float(selection[i][0][16])-210) ** 2))
            if(theta < theta0 - 4 * 0.0174532925 or theta > theta0 + 4 * 0.0174532925 and tempin != 0 and tempout != 0):
                TOF_in_He3bar_T.pop()
                TOF_out_He3bar_T.pop()
                TOF_out_He3bar_E.pop()
                TOF_in_He3bar_E.pop() 
                index.pop()
            break
    print("TOF data process:"+str(int(100*i/len(selection)))+"%", end='\r')

print("\n identification:finished!")
index = array([float(i) for i in index])
time_He3bar = array([float(i) for i in TOF_in_He3bar_T]) - array([float(i) for i in TOF_out_He3bar_T])
dEOut_He3bar = array([float(i) for i in TOF_out_He3bar_E])
dEIn_He3bar = array([float(i) for i in TOF_in_He3bar_E])
#plt.scatter(time_He3bar, dE_He3bar)
anti_proton = np.array([dEOut_He3bar, dEIn_He3bar, time_He3bar, index]).transpose()
plt.scatter(time_He3bar, dEOut_He3bar, marker = '.', color = 'b', label = 'TOF out layer')
plt.scatter(time_He3bar, dEIn_He3bar, marker = '.', color = 'r', label = 'TOF inner layer')
plt.title('antiHe3 TOF')
plt.xlabel('Time [ns]')
plt.ylabel('Energy diposit')
plt.legend(loc='lower right')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)
#np.savetxt('/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_proton_1e7_0_500_45_4_result.txt', anti_proton, delimiter = '\t ', fmt='%.6s')
with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/TOF_anti_He3_1e7_0_1500_0_4_result.txt", "ab") as f:    #input file
#with open("/Users/jiancheng/CloudDocuments/Documents/Github/GRAMS/GRAMS_2021/output/TOF/test.txt", "ab") as f:    #test run
    #f.write(b"\n")
    np.savetxt(f, anti_proton)
print("finished!")
