# %%
"""
split large data files
@aurthor Jiancheng Zeng
@October 13 2021
"""
# Out:
# '\nsplit large data files\n@aurthor Jiancheng Zeng\n@October 13 2021\n'

# %%
NUM_OF_LINES=10000000
filename = '/HDD/jiancheng/GRAMS/ToyModelData/geant11/vertical_anti_He3_0_1500_1e6.dat'
print("Reading files...")
with open(filename) as fin:
    fout = open("/HDD/jiancheng/GRAMS/ToyModelData/geant11/vertical_anti_He3_0_1500_1e6/vertical_anti_He3_0_1500_1e6_1.txt","wb")
    for i, line in enumerate(fin):
        fout.write(line.encode())
        if (i+1)%NUM_OF_LINES == 0:
            fout.close()
            fout = open("/HDD/jiancheng/GRAMS/ToyModelData/geant11/vertical_anti_He3_0_1500_1e6/vertical_anti_He3_0_1500_1e6_%d.txt"%(i/NUM_OF_LINES + 1), "wb")
            print("Finish file "+str(int(i/NUM_OF_LINES)))
    fout.close()
print("Finished!")
# Out:
# Reading files...
# Finish file 0
# Finish file 1
# Finish file 2
# Finish file 3
# Finish file 4
# Finish file 5
# Finish file 6
# Finish file 7
# Finish file 8
# Finish file 9
# Finish file 10
# Finish file 11
# Finish file 12
# Finish file 13
# Finish file 14
# Finish file 15
# Finish file 16
# Finish file 17
# Finish file 18
# Finish file 19
# Finish file 20
# Finish file 21
# Finish file 22
# Finish file 23
# Finish file 24
# Finish file 25
# Finish file 26
# Finish file 27
# Finish file 28
# Finish file 29
# Finish file 30
# Finish file 31
# Finish file 32
# Finish file 33
# Finish file 34
# Finish file 35
# Finish file 36
# Finish file 37
# Finish file 38
# Finish file 39
# Finish file 40
# Finish file 41
# Finish file 42
# Finish file 43
# Finish file 44
# Finish file 45
# Finish file 46
# Finish file 47
# Finish file 48
# Finish file 49
# Finish file 50
# Finish file 51
# Finish file 52
# Finish file 53
# Finish file 54
# Finish file 55
# Finish file 56
# Finish file 57
# ...
