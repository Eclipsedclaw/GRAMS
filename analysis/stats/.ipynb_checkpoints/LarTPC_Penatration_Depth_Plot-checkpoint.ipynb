# %%
"""
plot LArTPC penetration depth for three particles
@aurthor Jiancheng Zeng
@Oct 29 2021
"""
# Out:
# '\nplot LArTPC penetration depth for three particles\n@aurthor Jiancheng Zeng\n@Oct 29 2021\n'

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics
from numpy import array
import pandas as pd
import math
pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# %%
anti_proton = np.array(pd.read_table("/Users/jiancheng/GRAMS/data/TOF/No_Button_TPC140_GRASP_anti_proton_1e8_MeV_vector.txt", delimiter = ' '))
anti_deuteron = np.array(pd.read_table("/Users/jiancheng/GRAMS/data/TOF/No_button_TPC140_GRASP_anti_deuteron_1e8_MeV_Vector.txt", delimiter = ' '))
anti_He3 = np.array(pd.read_table("/Users/jiancheng/GRAMS/data/TOF/No_Button_TPC140_GRASP_anti_He3_1e8_MeV_vector.txt", delimiter = ' '))
print("Finish reading data!")
# Out:
# Finish reading data!

# %%
plt.hist(anti_proton[:, 6], bins = 40, label = "antiproton %d events"%len(anti_proton[:, 6]), color = 'b')

plt.title('antiproton stop events distance in LArTPC')
plt.xlabel('Penetration Distance/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("Number of events less than 1.6m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<160])/len(anti_proton[:, 6])))
print("Number of events less than 1.4m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<140])/len(anti_proton[:, 6])))
print("Number of events less than 1.2m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<120])/len(anti_proton[:, 6])))
print("Number of events less than 1.0m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<100])/len(anti_proton[:, 6])))
print("Number of events less than 0.8m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<80])/len(anti_proton[:, 6])))
print("Number of events less than 0.6m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<60])/len(anti_proton[:, 6])))
print("Number of events less than 0.4m:"+str(len(anti_proton[:, 6][anti_proton[:, 6]<40])/len(anti_proton[:, 6])))
# Out:
# Number of events less than 1.6m:0.9964742039657405
# Number of events less than 1.4m:0.9795160610929968
# Number of events less than 1.2m:0.9261610945568574
# Number of events less than 1.0m:0.8397946925849077
# Number of events less than 0.8m:0.7305730198599042
# Number of events less than 0.6m:0.6104307399491412
# Number of events less than 0.4m:0.4957955662334826

# %%
plt.hist(anti_deuteron[:, 6], bins = 40, label = "antideuteron %d events"%len(anti_deuteron[:, 6]), color = 'b')

plt.title('antideuteron stop events distance in LArTPC')
plt.xlabel('Penetration Distance/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("Number of events less than 1.6m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<400])/len(anti_deuteron[:, 6])))
print("Number of events less than 1.4m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<120])/len(anti_deuteron[:, 6])))
print("Number of events less than 1.2m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<110])/len(anti_deuteron[:, 6])))
print("Number of events less than 1.0m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<100])/len(anti_deuteron[:, 6])))
print("Number of events less than 0.8m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<90])/len(anti_deuteron[:, 6])))
print("Number of events less than 0.6m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<80])/len(anti_deuteron[:, 6])))
print("Number of events less than 0.4m:"+str(len(anti_deuteron[:, 6][anti_deuteron[:, 6]<70])/len(anti_deuteron[:, 6])))
# Out:
# Number of events less than 1.6m:0.9995332682501837
# Number of events less than 1.4m:0.5444853699043589
# Number of events less than 1.2m:0.5180761317272575
# Number of events less than 1.0m:0.492429222074856
# Number of events less than 0.8m:0.4681902865344001
# Number of events less than 0.6m:0.4452465315996842
# Number of events less than 0.4m:0.4241269199205

# %%
plt.hist(anti_He3[:, 6], bins = 40, label = "antiHe3 %d events"%len(anti_He3[:, 6]), color = 'b')

plt.title('antiproton stop events distance in LArTPC')
plt.xlabel('Penetration Distance/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("Number of events less than 1.6m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<160])/len(anti_He3[:, 6])))
print("Number of events less than 1.4m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<140])/len(anti_He3[:, 6])))
print("Number of events less than 1.2m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<120])/len(anti_He3[:, 6])))
print("Number of events less than 1.0m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<100])/len(anti_He3[:, 6])))
print("Number of events less than 0.8m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<80])/len(anti_He3[:, 6])))
print("Number of events less than 0.6m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<60])/len(anti_He3[:, 6])))
print("Number of events less than 0.4m:"+str(len(anti_He3[:, 6][anti_He3[:, 6]<40])/len(anti_He3[:, 6])))
# Out:
# Number of events less than 1.6m:0.9958768061381807
# Number of events less than 1.4m:0.9781829263920261
# Number of events less than 1.2m:0.9235954250475064
# Number of events less than 1.0m:0.8337815065791833
# Number of events less than 0.8m:0.7217023412570364
# Number of events less than 0.6m:0.6033846043526586
# Number of events less than 0.4m:0.4874152952565344

# %%
plt.hist(anti_proton[:, 7], bins = 40, range = (0, 20), label = "antiproton %d events"%len(anti_proton[:, 7]), color = 'b')

plt.title('antiproton stop events depth in LArTPC')
plt.xlabel('Penetration Depth/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("ratio of events less than 18cm:"+str(int(100*len(anti_proton[:, 7][anti_proton[:, 7]<18])/len(anti_proton[:, 7])))+"%")
print("ratio of events less than 16cm:"+str(int(100*len(anti_proton[:, 7][anti_proton[:, 7]<16])/len(anti_proton[:, 7])))+"%")
print("ratio of events less than 15cm:"+str(int(100*len(anti_proton[:, 7][anti_proton[:, 7]<15])/len(anti_proton[:, 7])))+"%")
print("ratio of events less than 14cm:"+str(int(100*len(anti_proton[:, 7][anti_proton[:, 7]<14])/len(anti_proton[:, 7])))+"%")
print("ratio of events less than 12cm:"+str(int(100*len(anti_proton[:, 7][anti_proton[:, 7]<12])/len(anti_proton[:, 7])))+"%")
print("ratio of events less than 10cm:"+str(int(100*len(anti_proton[:, 7][anti_proton[:, 7]<10])/len(anti_proton[:, 7])))+"%")
print("ratio of events less than 8cm:"+str(int(100*len(anti_proton[:, 7][anti_proton[:, 7]<8])/len(anti_proton[:, 7])))+"%")
print("ratio of events less than 6cm:"+str(int(100*len(anti_proton[:, 7][anti_proton[:, 7]<6])/len(anti_proton[:, 7])))+"%")
# Out:
# ratio of events less than 18cm:93%
# ratio of events less than 16cm:86%
# ratio of events less than 15cm:82%
# ratio of events less than 14cm:78%
# ratio of events less than 12cm:70%
# ratio of events less than 10cm:61%
# ratio of events less than 8cm:51%
# ratio of events less than 6cm:41%

# %%
plt.hist(anti_deuteron[:, 7], bins = 40, range = (0, 20), label = "antideuteron %d events"%len(anti_deuteron[:, 7]), color = 'b')

plt.title('antideuteron stop events depth in LArTPC')
plt.xlabel('Penetration Depth/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("ratio of events less than 18cm:"+str(int(100*len(anti_deuteron[:, 7][anti_deuteron[:, 7]<18])/len(anti_deuteron[:, 7])))+"%")
print("ratio of events less than 16cm:"+str(int(100*len(anti_deuteron[:, 7][anti_deuteron[:, 7]<16])/len(anti_deuteron[:, 7])))+"%")
print("ratio of events less than 15cm:"+str(int(100*len(anti_deuteron[:, 7][anti_deuteron[:, 7]<15])/len(anti_deuteron[:, 7])))+"%")
print("ratio of events less than 14cm:"+str(int(100*len(anti_deuteron[:, 7][anti_deuteron[:, 7]<14])/len(anti_deuteron[:, 7])))+"%")
print("ratio of events less than 12cm:"+str(int(100*len(anti_deuteron[:, 7][anti_deuteron[:, 7]<12])/len(anti_deuteron[:, 7])))+"%")
print("ratio of events less than 10cm:"+str(int(100*len(anti_deuteron[:, 7][anti_deuteron[:, 7]<10])/len(anti_deuteron[:, 7])))+"%")
print("ratio of events less than 8cm:"+str(int(100*len(anti_deuteron[:, 7][anti_deuteron[:, 7]<8])/len(anti_deuteron[:, 7])))+"%")
print("ratio of events less than 6cm:"+str(int(100*len(anti_deuteron[:, 7][anti_deuteron[:, 7]<6])/len(anti_deuteron[:, 7])))+"%")
# Out:
# ratio of events less than 18cm:94%
# ratio of events less than 16cm:88%
# ratio of events less than 15cm:85%
# ratio of events less than 14cm:81%
# ratio of events less than 12cm:74%
# ratio of events less than 10cm:65%
# ratio of events less than 8cm:56%
# ratio of events less than 6cm:45%

# %%
plt.hist(anti_He3[:, 7], bins = 40, range = (0, 20), label = "antiHe3 %d events"%len(anti_He3[:, 7]), color = 'b')

plt.title('antiHe3 stop events depth in LArTPC')
plt.xlabel('Penetration Depth/cm')
plt.ylabel('number of events')
plt.legend(loc='best')
#plt.axis([0, 20, 0, 10])
plt.grid(alpha = 0.2)

print("ratio of events less than 18cm:"+str(int(100*len(anti_He3[:, 7][anti_He3[:, 7]<18])/len(anti_He3[:, 7])))+"%")
print("ratio of events less than 16cm:"+str(int(100*len(anti_He3[:, 7][anti_He3[:, 7]<16])/len(anti_He3[:, 7])))+"%")
print("ratio of events less than 14cm:"+str(int(100*len(anti_He3[:, 7][anti_He3[:, 7]<14])/len(anti_He3[:, 7])))+"%")
print("ratio of events less than 12cm:"+str(int(100*len(anti_He3[:, 7][anti_He3[:, 7]<12])/len(anti_He3[:, 7])))+"%")
print("ratio of events less than 10cm:"+str(int(100*len(anti_He3[:, 7][anti_He3[:, 7]<10])/len(anti_He3[:, 7])))+"%")
print("ratio of events less than 8cm:"+str(int(100*len(anti_He3[:, 7][anti_He3[:, 7]<8])/len(anti_He3[:, 7])))+"%")
print("ratio of events less than 6cm:"+str(int(100*len(anti_He3[:, 7][anti_He3[:, 7]<6])/len(anti_He3[:, 7])))+"%")
# Out:
# ratio of events less than 18cm:93%
# ratio of events less than 16cm:87%
# ratio of events less than 14cm:80%
# ratio of events less than 12cm:72%
# ratio of events less than 10cm:64%
# ratio of events less than 8cm:54%
# ratio of events less than 6cm:43%
