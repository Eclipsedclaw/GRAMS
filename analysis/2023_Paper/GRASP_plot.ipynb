# %%
"""
Analyze GRASP of antihelium3 for ICRC 2023
author: Jiancheng Zeng
Date: July 15, 2023
"""
# Out:
# '\nAnalyze GRASP of antihelium3 for ICRC 2023\nauthor: Jiancheng Zeng\nDate: July 15, 2023\n'

# %%
"""
RUN THIS BLOCK before others!
You don't need to change anything in this code block unless you want to define your own changes.
This block is for defining functions that will be used for analysis
"""

import pandas as pd
import numpy as np
import time
import math
import matplotlib.pyplot as plt
import toy_model_analysis
import h5py
import pickle

# %%
file_path_GRASP_5e7_140_antiHe3 = '/home/jiancheng/GRAMS/GRAMS_work/output/2025/GRASP_anti_He3_5e7_0_3000_GPS.dat'

file_path_GRASP_5e7_140_antiproton = '/home/jiancheng/GRAMS/GRAMS_work/output/2025/GRASP_anti_proton_5e7_0_1000_GPS.dat'

# %%
file_path_GRASP_5e7_320_antiHe3 = '/home/jiancheng/GRAMS/GRAMS_work/output/2025/GRASP_MAX_anti_He3_5e7_0_3000_GPS.dat'


file_path_GRASP_5e7_320_antiproton = '/home/jiancheng/GRAMS/GRAMS_work/output/2025/GRASP_MAX_anti_proton_5e7_0_1000_GPS.dat'

# %%
#GRASP_vector = toy_model_analysis.Analyze_GRASP(toy_model_analysis.read_data_from_toymodel(file_path_GRASP_5e7_320_antiHe3), -1000020030, stop_event=False, in_flight_event=True)
# Save both objects to a single file
#with open('saved_vector/GRASP_5e7_320_antiHe3_inflight.pkl', 'wb') as f:
#    pickle.dump((GRASP_vector[0], GRASP_vector[1]), f)

#print("Data saved!")

# %%
fig, ax = plt.subplots(figsize=(16, 16))

# Load the data from the file
with open('saved_vector/GRASP_5e7_320_antiHe3_stop.pkl', 'rb') as f:
    loaded_energy_array, loaded_event_count = pickle.load(f)
label_GRASP_5e7_140_antiHe3= 'Satellite AntiHelium3 annihilation events after stop inside LArTPC'
# variable explaination: toy_model_analysis.GRASP_hist(GRASP_vector_from_toy_model_analysis.Analyze_GRASP_function, Particle_ID_of_initial_particle, label, total_number_of_events, minimal_ernegy, maximum_energy, number_of_bins, plot_ax_name)
plot_1e7_140_Stop_antiHe3 = toy_model_analysis.GRASP_hist(loaded_energy_array, -1000020030, label_GRASP_5e7_140_antiHe3, loaded_event_count, 0, 3000, 100, color='blue', alpha=0.8, ax=ax)

# Load the data from the file
with open('saved_vector/GRASP_5e7_320_antiHe3_inflight.pkl', 'rb') as f:
    loaded_energy_array, loaded_event_count = pickle.load(f)
label_GRASP_5e7_140_antiHe3_inflight= 'Satellite AntiHelium3 annihilation in flight events inside LArTPC'
# variable explaination: toy_model_analysis.GRASP_hist(GRASP_vector_from_toy_model_analysis.Analyze_GRASP_function, Particle_ID_of_initial_particle, label, total_number_of_events, minimal_ernegy, maximum_energy, number_of_bins, plot_ax_name)
plot_1e7_140 = toy_model_analysis.GRASP_hist(loaded_energy_array, -1000020030, label_GRASP_5e7_140_antiHe3_inflight, loaded_event_count, 0, 3000, 100, color='blue', alpha=0.3, ax=ax)

# Load the data from the file
with open('saved_vector/GRASP_5e7_320_antiproton_stop.pkl', 'rb') as f:
    loaded_energy_array, loaded_event_count = pickle.load(f)
label_GRASP_5e7_140_antiproton= 'Satellite Antiproton annihilation events after stop inside LArTPC'
# variable explaination: toy_model_analysis.GRASP_hist(GRASP_vector_from_toy_model_analysis.Analyze_GRASP_function, Particle_ID_of_initial_particle, label, total_number_of_events, minimal_ernegy, maximum_energy, number_of_bins, plot_ax_name)
plot_1e7_140_Stop = toy_model_analysis.GRASP_hist(loaded_energy_array, -2212, label_GRASP_5e7_140_antiproton, loaded_event_count, 0, 1000, 100, color='red', alpha=0.8, ax=ax)

# Load the data from the file
with open('saved_vector/GRASP_5e7_320_antiproton_inflight.pkl', 'rb') as f:
    loaded_energy_array, loaded_event_count = pickle.load(f)
label_GRASP_5e7_140_antiproton_inflight= 'Satellite Antiproton annihilation in flight events inside LArTPC'
# variable explaination: toy_model_analysis.GRASP_hist(GRASP_vector_from_toy_model_analysis.Analyze_GRASP_function, Particle_ID_of_initial_particle, label, total_number_of_events, minimal_ernegy, maximum_energy, number_of_bins, plot_ax_name)
plot_1e7_140 = toy_model_analysis.GRASP_hist(loaded_energy_array, -2212, label_GRASP_5e7_140_antiproton_inflight, loaded_event_count, 0, 1000, 100, color='red', alpha=0.3, ax=ax)

# Load the data from the file
with open('saved_vector/GRASP_noatmos_5e7_320_antiHe3_stop.pkl', 'rb') as f:
    loaded_energy_array, loaded_event_count = pickle.load(f)
label_GRASP_5e7_320_antiHe3= 'No atmos Satellite AntiHelium3 annihilation events after stop inside LArTPC'
# variable explaination: toy_model_analysis.GRASP_hist(GRASP_vector_from_toy_model_analysis.Analyze_GRASP_function, Particle_ID_of_initial_particle, label, total_number_of_events, minimal_ernegy, maximum_energy, number_of_bins, plot_ax_name)
plot_1e7_320_Stop = toy_model_analysis.GRASP_hist(loaded_energy_array, -1000020030, label_GRASP_5e7_320_antiHe3, loaded_event_count, 0, 3000, 100, color='blue', alpha=0.8, ax=ax, linestyle='--')

# Load the data from the file
with open('saved_vector/GRASP_noatmos_5e7_320_antiHe3_inflight.pkl', 'rb') as f:
    loaded_energy_array, loaded_event_count = pickle.load(f)
label_GRASP_5e7_320_antiHe3_inflight= 'No atmos Satellite AntiHelium3 annihilation in flight events inside LArTPC'
# variable explaination: toy_model_analysis.GRASP_hist(GRASP_vector_from_toy_model_analysis.Analyze_GRASP_function, Particle_ID_of_initial_particle, label, total_number_of_events, minimal_ernegy, maximum_energy, number_of_bins, plot_ax_name)
plot_1e7_320 = toy_model_analysis.GRASP_hist(loaded_energy_array, -1000020030, label_GRASP_5e7_320_antiHe3_inflight, loaded_event_count, 0, 3000, 100, color='blue', alpha=0.3, ax=ax, linestyle='--')

# Load the data from the file
with open('saved_vector/GRASP_noatmos_5e7_320_antiproton_stop.pkl', 'rb') as f:
    loaded_energy_array, loaded_event_count = pickle.load(f)
label_GRASP_5e7_320_antiproton= 'No atmos Satellite Antiproton annihilation events after stop inside LArTPC'
# variable explaination: toy_model_analysis.GRASP_hist(GRASP_vector_from_toy_model_analysis.Analyze_GRASP_function, Particle_ID_of_initial_particle, label, total_number_of_events, minimal_ernegy, maximum_energy, number_of_bins, plot_ax_name)
plot_1e7_320_Stop = toy_model_analysis.GRASP_hist(loaded_energy_array, -2212, label_GRASP_5e7_320_antiproton, loaded_event_count, 0, 1000, 100, color='red', alpha=0.8, ax=ax, linestyle='--')

# Load the data from the file
with open('saved_vector/GRASP_noatmos_5e7_320_antiproton_inflight.pkl', 'rb') as f:
    loaded_energy_array, loaded_event_count = pickle.load(f)
label_GRASP_5e7_320_antiproton_inflight= 'No atmos Satellite Antiproton annihilation in flight events inside LArTPC'
# variable explaination: toy_model_analysis.GRASP_hist(GRASP_vector_from_toy_model_analysis.Analyze_GRASP_function, Particle_ID_of_initial_particle, label, total_number_of_events, minimal_ernegy, maximum_energy, number_of_bins, plot_ax_name)
plot_1e7_320 = toy_model_analysis.GRASP_hist(loaded_energy_array, -2212, label_GRASP_5e7_320_antiproton_inflight, loaded_event_count, 0, 1000, 100, color='red', alpha=0.3, ax=ax, linestyle='--')

plt.show()  # Display the plot with both data on the same axes

# %%
print(toy_model_analysis.number_of_nucleons(-1000020030)[1])
# Out:
# 3
