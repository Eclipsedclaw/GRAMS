# %%
"""
Toy model sample code
author: Jiancheng Zeng
Date: May 20, 2024
"""
# Out:
# '\nAnalyze GRASP for each detector design\nauthor: Jiancheng Zeng\nDate: May 1, 2023\n'

# %%
"""
RUN THIS BLOCK before others!
You don't need to change anything in this code block unless you want to define your own changes.
This block is for defining functions that will be used for analysis
"""

import pandas as pd
import numpy as np
import time
import math
import matplotlib.pyplot as plt
import sys
import os
sys.path.insert(0, '')
import toy_model_analysis
import h5py

# %%
# Change this path to your actual data path. Now I'm using the example data. This will generate a h5 file for you to do further analysis
toy_model_analysis.read_data_from_toymodel("./test.dat")
# Out:
# Reading data...
#
# test.h5
# /home/jiancheng/GRAMS/GRAMS_work/2023_Paper/toy_model_analysis.py:103: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for event_index, (eventID, group_df) in enumerate(grouped_data):
# [##################################################] 100.00% 13/13Toy Model data imported
# Found 13 Events!

# %%
# Use the h5 file that just processed from previous to call certain events
# this displays all the event numbers, corresponding to each events you generated
event_number = toy_model_analysis.list_eventID(file_path='./test.h5')

# this display all the tracks inside a certain events, you have to input event ID based on the result from the event list you have from previous line
trackID = toy_model_analysis.list_trackID(file_path='./test.h5', eventID=176)

# this actually calls all the data for a specific track. From this you could check detailed data
data = toy_model_analysis.list_track_data(file_path='./test.h5', eventID=176, trackID=1)
print(data)
# Out:
# event numbers(only display 10 here): ['176', '4270', '430', '4661', '5197', '5823', '6511', '717', '7190', '829']
# ...
