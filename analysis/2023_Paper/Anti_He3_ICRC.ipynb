# %%
"""
Analyze GRASP of antihelium3 for ICRC 2023
author: Jiancheng Zeng
Date: July 15, 2023
"""
# Out:
# '\nAnalyze GRASP of antihelium3 for ICRC 2023\nauthor: Jiancheng Zeng\nDate: July 15, 2023\n'

# %%
"""
RUN THIS BLOCK before others!
You don't need to change anything in this code block unless you want to define your own changes.
This block is for defining functions that will be used for analysis
"""

import pandas as pd
import numpy as np
import time
import math
import matplotlib.pyplot as plt
import toy_model_analysis

# %%
fig, ax = plt.subplots(figsize=(16, 10))

Events_1300_In_Flight = []
TPC_length_1300 = []

plt.figure(1)

file_path_atmo_anti_He3_1e7_140 = '/home/jiancheng/GRAMS/toymodel_work/output/2023/GRASP_anti_He3_atmo_1e7_140cm_1300kgTPC.dat'
label_140cm_Stop= 'AntiHelium3 annihilation events after stop inside LArTPC'
label_140cm_In_Flight= 'AntiHelium3 annihilation in flight events inside LArTPC'

# variable explaination: toy_model_analysis.Analyze_GRASP(data_vector_constructed, Particle_ID_of_initial_particle, stop_event_inside_LAr, in_flight_event_inside_LAr)
GRASP_1e7_140_Stop = toy_model_analysis.Analyze_GRASP(toy_model_analysis.read_data_from_toymodel(file_path_atmo_anti_He3_1e7_140), -1000010020, stop_event=True, in_flight_event=False)

# variable explaination: toy_model_analysis.GRASP_hist(GRASP_vector_from_toy_model_analysis.Analyze_GRASP_function, Particle_ID_of_initial_particle, label, total_number_of_events, minimal_ernegy, maximum_energy, number_of_bins, plot_ax_name)
plot_1e7_140_Stop = toy_model_analysis.GRASP_hist(GRASP_1e7_140_Stop[0], -1000020030, label_140cm_Stop, GRASP_1e7_140_Stop[1], 0, 1500, 50, ax=ax)
GRASP_1e7_140 = None

# variable explaination: toy_model_analysis.Analyze_GRASP(data_vector_constructed, Particle_ID_of_initial_particle, stop_event_inside_LAr, in_flight_event_inside_LAr)
GRASP_1e7_140_In_Flgiht = toy_model_analysis.Analyze_GRASP(toy_model_analysis.read_data_from_toymodel(file_path_atmo_anti_He3_1e7_140), -1000010020, stop_event=False, in_flight_event=True)

# variable explaination: toy_model_analysis.GRASP_hist(GRASP_vector_from_toy_model_analysis.Analyze_GRASP_function, Particle_ID_of_initial_particle, label, total_number_of_events, minimal_ernegy, maximum_energy, number_of_bins, plot_ax_name)
plot_1e7_140 = toy_model_analysis.GRASP_hist(GRASP_1e7_140_In_Flgiht[0], -1000020030, label_140cm_In_Flight, GRASP_1e7_140_In_Flgiht[1], 0, 1500, 50, ax=ax)
GRASP_1e7_140 = None

plt.show()  # Display the plot with both data on the same axes
# Out:
# Reading data...
#
# Toy Model data imported
# Found 15401 Events!
# Now processing (15400/15401)
#  We got 5965 events selected
# Last event is 9999880
# Reading data...
#
# Toy Model data imported
# Found 15401 Events!
# Now processing (15400/15401)
#  We got 9436 events selected
# Last event is 9999880
